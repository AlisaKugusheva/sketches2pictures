# %%
from PIL import Image 
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
from preprocess_images import transform, save_img_and_masks

# %% [markdown]
# ##### Example of applying transform

# %%
list_of_images = glob.glob('./img_no_background/*.jpg')
img = cv2.imread(list_of_images[0])
plt.imshow(img);

# %%
img.shape
# Out:
# (1280, 1918, 3)

# %%
plt.imshow(transform(img, size=(350, 270), crop_size=(256, 256)));

# %%
img.shape
# Out:
# (1280, 1918, 3)

# %% [markdown]
# ##### Example  of applying save_img_and_masks

# %%
for i, path in tqdm(enumerate(list_of_images[:10])):
    save_img_and_masks(img_path=path,
                   dataset_path='cars/', 
                   index=i, 
                   size=(350, 270),
                   crop_size=(256,256),
                   canny_threshold_1=80,
                   canny_threshold_2=120)
# Out:
# 10it [00:00, 31.39it/s]

# %%
plt.imshow(cv2.imread('/Users/alisakugusheva/573/cars/0.jpg'));
