# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2443, done.
# remote: Total 2443 (delta 0), reused 0 (delta 0), pack-reused 2443
# Receiving objects: 100% (2443/2443), 8.13 MiB | 20.98 MiB/s, done.
# Resolving deltas: 100% (1570/1570), done.

# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 676 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 32.9 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 180 kB 52.6 MB/s
# ...
#      |████████████████████████████████| 97 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 140 kB 25.7 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=ae676c30b0c51eb047a1e66812ec2d04a8498fc5cc1c3e94a09949cb222b9077
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=ed1fab27dc9ee51136fa44ff7e5694bb8ebbe87383d240dfcb7f8ee40b2989f8
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# ...

# %% [markdown]
# ## Download pre-trained model

# %%
# !bash ./scripts/download_pix2pix_model.sh edges2shoes
# Out:
# Note: available models are edges2shoes, sat2map, map2sat, facades_label2photo, and day2night
# Specified [edges2shoes]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2021-11-30 17:52:20--  http://efrosgans.eecs.berkeley.edu/pix2pix/models-pytorch/edges2shoes.pth
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.244.190|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 217704688 (208M)
# Saving to: ‘./checkpoints/edges2shoes_pretrained/latest_net_G.pth’
#
# ./checkpoints/edges 100%[===================>] 207.62M  2.42MB/s    in 98s
#
# 2021-11-30 17:53:58 (2.11 MB/s) - ‘./checkpoints/edges2shoes_pretrained/latest_net_G.pth’ saved [217704688/217704688]

# %%
dataset_path = '/content/drive/MyDrive/INF573/cars/'

# %% [markdown]
# ## Train the model

# %%
# !python train.py --dataroot '/content/drive/MyDrive/INF573/cars/' --name edges2cars --model pix2pix --gpu_ids 0 --direction BtoA
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: /content/drive/MyDrive/INF573/cars/	[default: None]
#              dataset_mode: aligned
#                 direction: BtoA                          	[default: AtoB]
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: vanilla
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
# ...

# %%
# !python test.py --dataroot '/content/drive/MyDrive/INF573/cars/' --model pix2pix --name edges2cars --gpu_ids 0 --direction BtoA
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: /content/drive/MyDrive/INF573/cars/	[default: None]
#              dataset_mode: aligned
#                 direction: BtoA                          	[default: AtoB]
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
# ...

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/edges2cars/test_latest/images/955_fake_B.png')
plt.imshow(img);

# %%
img = plt.imread('./results/edges2cars/test_latest/images/956_fake_B.png')
plt.imshow(img);

# %%
img = plt.imread('./results/edges2cars/test_latest/images/957_fake_B.png')
plt.imshow(img);

# %%
img = plt.imread('./results/edges2cars/test_latest/images/958_fake_B.png')
plt.imshow(img);

# %%
img = plt.imread('./results/edges2cars/test_latest/images/959_fake_B.png')
plt.imshow(img);
